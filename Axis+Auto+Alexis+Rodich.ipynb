# %%
path_to_zip_file = "datasets.zip"
directory_to_extract_to = ""

import zipfile
zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
zip_ref.extractall(directory_to_extract_to)
zip_ref.close()

# %%
import pandas as pd

Location = "datasets/axisdata.csv"
df= pd.read_csv(Location, header=None)

# %%
df.head()
# Out:
#          0          1       2             3              4                 5  \
# 0    Fname      Lname  Gender  Hours Worked  SalesTraining  Years Experience
# 1     Jada   Walters        F            39              N                 3
# 2   Nicole  Henderson       F            46              N                 3
# 3    Tanya      Moore       F            42              Y                 4
# 4  Ronelle    Jackson       F            38              Y                 5
#
#            6
# 0  Cars Sold
# 1          2
# 2          6
# 3          6
# 4          3

# %%
df.columns = ['First','Last', 'Gender', 'HoursWorked', 'SalesTraining','YearsExperience','CarsSold']

# %%
df.head()
# Out:
#      First       Last  Gender   HoursWorked  SalesTraining   YearsExperience  \
# 0    Fname      Lname  Gender  Hours Worked  SalesTraining  Years Experience
# 1     Jada   Walters        F            39              N                 3
# 2   Nicole  Henderson       F            46              N                 3
# 3    Tanya      Moore       F            42              Y                 4
# 4  Ronelle    Jackson       F            38              Y                 5
#
#     CarsSold
# 0  Cars Sold
# 1          2
# 2          6
# 3          6
# 4          3

# %%
# Drop Duplicates

df.drop_duplicates()
# Out:
#         First       Last  Gender   HoursWorked  SalesTraining  \
# 0       Fname      Lname  Gender  Hours Worked  SalesTraining
# 1        Jada   Walters        F            39              N
# 2      Nicole  Henderson       F            46              N
# 3       Tanya      Moore       F            42              Y
# 4     Ronelle    Jackson       F            38              Y
# 5        Brad      Sears       M            33              N
# 6      Jackie     Rogers       F            45              Y
# 7      Oliver     Vaughn       M            46              N
# 8       Carla       Sapp       F            39              Y
# 9       Karen      Moore       F            33              Y
# 10      Roger       Kane       M            38              N
# 11     Jackie    Jackson       F            32              Y
# 12        Sam   Isaacson       M            39              N
# 13      Aaron   Isaacson       M            46              Y
# 14      David    Johnson       M            23              Y
# 15        Sam   Harrison       M            43              N
# 16       Mary  Patterson       F            43              N
# 17      Frank      Baker       M            26              N
# 18      Tanya      Adams       F            28              Y
# 19      Tanya  Henderson       F            24              Y
# 20      india    Withers       F            35              Y
# 21   Veronica    Withers       F            34              Y
# 22   Francine   Davidson       F            27              Y
# 23     Harold   Walters        M            41              N
# 24     Walter   Franklin       M            25              Y
# 25   Victoria   Ettienne       F            29              Y
# 26     Evelyn   Ettienne       F            37              Y
# 27       Mike      Sears       M            41              Y
# 28     Oliver    Martins       M            41              Y
# 29        Tom   Davidson       M            45              Y
# ..        ...        ...     ...           ...            ...
# 970  Veronica    Kennedy       F            43              Y
# 971      Mike       Kane       M            38              N
# 972   Charles      Baker       M            42              Y
# 973    Walter    Mulgrew       M            40              Y
# 974  Veronica    Johnson       F            46              Y
# 975     Frank     Rogers       M            27              N
# 976    Nicole      Adams       F            38              Y
# 977    Denise      Adams       F            37              N
# 978    Oliver     Carter       M            45              Y
# 979    August    Jackson       F            41              Y
# 980      Adam      Baker       M            36              Y
# 981       Sam    Withers       M            29              Y
# 982  Veronica     Looner       F            22              Y
# 983       Sam     Turner       M            40              Y
# 984      Lisa       Rose       F            40              Y
# 985    Oliver  Samuelson       M            45              N
# 986     Frank       Rose       M            26              Y
# 987     Larry     Monroe       M            32              N
# 988  Samantha       Sapp       F            38              Y
# 989      Adam       Sapp       M            37              Y
# 990    Victor  Samuelson       M            41              Y
# 991     Larry  Patterson       M            29              N
# 992    August    Kennedy       F            25              Y
# 993      Adam   Harrison       M            42              Y
# 994    Harold   Ettienne       M            35              Y
# 995    Victor       Kane       M            22              Y
# 996   Charles     Turner       M            45              N
# 997    August   Franklin       F            34              Y
# 998  Victoria     Rogers       F            29              N
# 999      Mike    Gerardo       M            20              N
#
#       YearsExperience   CarsSold
# 0    Years Experience  Cars Sold
# 1                   3          2
# 2                   3          6
# 3                   4          6
# 4                   5          3
# 5                   4          2
# 6                   5          3
# 7                   5          3
# 8                   3          6
# 9                   2          5
# 10                  4          5
# 11                  1          3
# 12                  4          6
# 13                  5          5
# 14                  4          6
# 15                  3          4
# 16                  1          6
# 17                  3          5
# 18                  1          2
# 19                  1          5
# 20                  4          5
# 21                  2          2
# 22                  4          4
# 23                  5          2
# 24                  1          4
# 25                  1          2
# 26                  5          6
# 27                  3          6
# 28                  5          3
# 29                  5          7
# ..                ...        ...
# 970                 4          4
# 971                 2          5
# 972                 3          3
# 973                 5          5
# 974                 4          3
# 975                 2          1
# 976                 2          2
# 977                 1          2
# 978                 2          5
# 979                 1          2
# 980                 2          6
# 981                 2          2
# 982                 5          4
# 983                 2          4
# 984                 4          2
# 985                 3          2
# 986                 3          6
# 987                 2          5
# 988                 1          3
# 989                 2          3
# 990                 2          6
# 991                 5          3
# 992                 3          5
# 993                 4          5
# 994                 2          5
# 995                 5          4
# 996                 1          4
# 997                 4          3
# 998                 5          1
# 999                 3          3
#
# [1000 rows x 7 columns]

# %%
# remove outliers

import pandas as pd

Location = "datasets/axisdata.csv"
df = pd.read_csv(Location)

meanhours = df['Hours Worked'].mean()
sthours = df['Hours Worked'].std()
toprange = meanhours + sthours*1.96
botrange = meanhours +sthours*1.96

copydf = df
copydf = copydf.drop(copydf[copydf['Hours Worked'] > toprange].index)
copydf = copydf.drop(copydf[copydf['Hours Worked'] < botrange].index)
copydf
# Out:
# Empty DataFrame
# Columns: [Fname, Lname, Gender, Hours Worked, SalesTraining, Years Experience, Cars Sold]
# Index: []

# %%
df.columns = ['First','Last', 'Gender', 'HoursWorked', 'SalesTraining','YearsExperience','CarsSold']

# %%
# Average Cars Sold 

df['CarsSold'].mean()
# Out:
# 3.9229229229229228

# %%
# max cars sold per month

df['CarsSold'].max()
# Out:
# 7

# %%
# min cars sold per month

df['CarsSold'].min()
# Out:
# 1

# %%
# average cars sold per month by gender (F)

female = df['Gender'] =='F'
df[female]['CarsSold'].mean()
# Out:
# 3.7607361963190185

# %%
# average cars sold per month by gender (F)

male = df['Gender'] =='M'
df[male]['CarsSold'].mean()
# Out:
# 4.078431372549019

# %%
# average hours worked by people selling > 3 cars per month

hivol = df['CarsSold']>=3

df[hivol]['HoursWorked'].mean()
# Out:
# 34.59642401021711

# %%
# average years of experience

df['YearsExperience'].mean()
# Out:
# 3.026026026026026

# %%
# average years of experience for people selling > 3 cars per month

hivol = df['CarsSold']>=3

df[hivol]['YearsExperience'].mean()
# Out:
# 3.0804597701149423

# %%
# average cars sold by training status 

pd.pivot_table(df, index=['SalesTraining'])
# Out:
#                CarsSold  HoursWorked  YearsExperience
# SalesTraining
# N              3.573850    33.474576         3.055690
# Y              4.168942    33.906143         3.005119

# %%
# Sales training is the best indicator of car sales
